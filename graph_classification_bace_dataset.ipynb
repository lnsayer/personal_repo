# %% [markdown]
# <a href="https://colab.research.google.com/github/lnsayer/personal_repo/blob/main/graph_classification_bace_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Installed rdkit, torch_geometric, deepchem, networkx, torchmetrics into google drive with pip. With this resource https://netraneupane.medium.com/how-to-install-libraries-permanently-in-google-colab-fb15a585d8a5
# This method ends up taking around 200s, whilst installing the libraries themselves takes around 100s which is more efficient.

# %%
from timeit import default_timer as timer

# %%
start_time = timer()
# !pip install rdkit
# !pip install torch_geometric
# !pip install deepchem
# !pip install networkx
# !pip install torchmetrics
end_time = timer()
print(f"Time for cell to run: {end_time-start_time:.4f}")
# Out:
# Collecting rdkit
#   Downloading rdkit-2024.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.1/35.1 MB 51.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdkit) (1.25.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit) (9.4.0)
# Installing collected packages: rdkit
# Successfully installed rdkit-2024.3.1
# Collecting torch_geometric
#   Downloading torch_geometric-2.5.3-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (4.66.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (1.11.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (2023.6.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.1.4)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.9.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (2.31.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.1.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (1.2.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (5.9.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch_geometric) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (2024.6.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->torch_geometric) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->torch_geometric) (3.5.0)
# Installing collected packages: torch_geometric
# Successfully installed torch_geometric-2.5.3
# Collecting deepchem
#   Downloading deepchem-2.8.0-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 11.6 MB/s eta 0:00:00
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from deepchem) (1.4.2)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.10/dist-packages (from deepchem) (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from deepchem) (2.0.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from deepchem) (1.2.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from deepchem) (1.12.1)
# Requirement already satisfied: scipy>=1.10.1 in /usr/local/lib/python3.10/dist-packages (from deepchem) (1.11.4)
# Requirement already satisfied: rdkit in /usr/local/lib/python3.10/dist-packages (from deepchem) (2024.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->deepchem) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->deepchem) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->deepchem) (2024.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit->deepchem) (9.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->deepchem) (3.5.0)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->deepchem) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->deepchem) (1.16.0)
# Installing collected packages: deepchem
# Successfully installed deepchem-2.8.0
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (3.3)
# Collecting torchmetrics
#   Downloading torchmetrics-1.4.0.post0-py3-none-any.whl (868 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 868.8/868.8 kB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (1.25.2)
# Requirement already satisfied: packaging>17.1 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (24.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (2.3.0+cu121)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics)
#   Downloading lightning_utilities-0.11.3.post0-py3-none-any.whl (26 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (67.7.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (4.12.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (3.15.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.10.0->torchmetrics)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.10.0->torchmetrics)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.10.0->torchmetrics)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.10.0->torchmetrics)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.10.0->torchmetrics)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.10.0->torchmetrics)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.10.0->torchmetrics)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.10.0->torchmetrics)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.10.0->torchmetrics)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.10.0->torchmetrics)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.10.0->torchmetrics)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->torchmetrics)
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 60.9 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->torchmetrics) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->torchmetrics) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, lightning-utilities, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torchmetrics
# Successfully installed lightning-utilities-0.11.3.post0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105 torchmetrics-1.4.0.post0
# Time for cell to run: 79.8075

# %%
# Import necessary modules
import requests
from pathlib import Path
import os.path as osp

from rdkit import Chem
from rdkit.Chem import Draw

import torch
import torch_geometric
from torch_geometric.data import InMemoryDataset, Dataset, Data
from torch_geometric.loader import DataLoader
from torch_geometric.nn import GCNConv, global_mean_pool, GraphConv, GATConv, MLP, GINConv, global_max_pool, SAGPooling, TopKPooling, GINEConv
from torch.nn import Linear, ReLU, Dropout, Softmax
import torch.nn as nn
import torch.nn.functional as F
from torchmetrics.classification import BinaryAUROC, BinaryPrecision, BinaryRecall


import deepchem as dc
from deepchem.feat.graph_data import GraphData

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from pandas import DataFrame

import networkx as nx

import random

from tqdm.auto import tqdm
from timeit import default_timer as timer

from IPython.display import Javascript
import pickle

# %%
import os
google_drive_path = Path("drive/MyDrive")
# Prints all subdirectories (takes ages)
for dirpath, dirnames, filenames in os.walk(google_drive_path):
  print(f"There are {len(dirnames)} directories and {len(filenames)} files in '{dirpath}'.")
# Out:
# There are 8 directories and 27 files in 'drive/MyDrive'.
# There are 3 directories and 103 files in 'drive/MyDrive/Peru 2019 Expedition'.
# There are 1 directories and 0 files in 'drive/MyDrive/Peru 2019 Expedition/Alex's Photos'.
# There are 0 directories and 418 files in 'drive/MyDrive/Peru 2019 Expedition/Alex's Photos/Peru 2019'.
# There are 0 directories and 0 files in 'drive/MyDrive/Peru 2019 Expedition/Emilie'.
# There are 0 directories and 0 files in 'drive/MyDrive/Peru 2019 Expedition/Groña'.
# There are 0 directories and 2 files in 'drive/MyDrive/Private'.
# There are 0 directories and 50 files in 'drive/MyDrive/Old phone photos'.
# There are 0 directories and 37 files in 'drive/MyDrive/Go_pro_gorge_du_verdon_2016'.
# There are 0 directories and 31 files in 'drive/MyDrive/Colab Notebooks'.
# There are 0 directories and 6 files in 'drive/MyDrive/udemy_ml_course_data'.
# There are 2 directories and 0 files in 'drive/MyDrive/bace_graph_project'.
# There are 2 directories and 0 files in 'drive/MyDrive/bace_graph_project/data'.
# There are 0 directories and 1 files in 'drive/MyDrive/bace_graph_project/data/raw'.
# There are 0 directories and 1515 files in 'drive/MyDrive/bace_graph_project/data/processed'.
# There are 1 directories and 0 files in 'drive/MyDrive/bace_graph_project/models'.
# There are 0 directories and 10 files in 'drive/MyDrive/bace_graph_project/models/gcn_models'.

# %%
bace_project_path = google_drive_path / "bace_graph_project"
bace_raw_path = bace_project_path / "data/raw"

# %%
# Check if Bace csv file has been downloaded, if not, download it
if bace_raw_path.is_dir():
  print(f"{bace_raw_path} is already a directory")
else:
  print(f"{bace_raw_path} is not a directory, creating one")
  bace_raw_path.mkdir(parents=True, exist_ok=True)

  with open(bace_raw_path / "bace.csv", "wb") as f:
    request = requests.get("https://raw.githubusercontent.com/lnsayer/personal_repo/main/drug%20discovery%20with%20BACE%20dataset/data/bace.csv")
    print("Downloading data")
    f.write(request.content)
# Out:
# drive/MyDrive/bace_graph_project/data/raw is already a directory

# %%
# If want to download bace csv straight into colab
data_path = Path("data/")
bace_path = data_path / "raw"

if bace_path.is_dir():
  print(f"{bace_path} is already a directory")
else:
  print(f"{bace_path} is not a directory, creating one")
  bace_path.mkdir(parents=True, exist_ok=True)

  with open(bace_path / "bace.csv", "wb") as f:
    request = requests.get("https://raw.githubusercontent.com/lnsayer/personal_repo/main/drug%20discovery%20with%20BACE%20dataset/data/bace.csv")
    print("Downloading data")
    f.write(request.content)
# Out:
# data/raw is not a directory, creating one
# Downloading data

# %%
bace_raw_path
# Out:
# PosixPath('drive/MyDrive/bace_graph_project/data/raw')

# %%
# Turn CSV file into a dataframe and resave it without unnecessary columns
bace_df = pd.read_csv(bace_raw_path/ "bace.csv")
bace_df = bace_df[["mol", "CID", "Class", "Model", "pIC50"]]
bace_df.to_csv(bace_raw_path/"bace.csv")

bace_df
# Out:
#                                                     mol        CID  Class  \
# 0     O1CC[C@@H](NC(=O)[C@@H](Cc2cc3cc(ccc3nc2N)-c2c...     BACE_1      1
# 1     Fc1cc(cc(F)c1)C[C@H](NC(=O)[C@@H](N1CC[C@](NC(...     BACE_2      1
# 2     S1(=O)(=O)N(c2cc(cc3c2n(cc3CC)CC1)C(=O)N[C@H](...     BACE_3      1
# 3     S1(=O)(=O)C[C@@H](Cc2cc(O[C@H](COCC)C(F)(F)F)c...     BACE_4      1
# 4     S1(=O)(=O)N(c2cc(cc3c2n(cc3CC)CC1)C(=O)N[C@H](...     BACE_5      1
# ...                                                 ...        ...    ...
# 1508          Clc1cc2nc(n(c2cc1)C(CC(=O)NCC1CCOCC1)CC)N  BACE_1543      0
# 1509          Clc1cc2nc(n(c2cc1)C(CC(=O)NCc1ncccc1)CC)N  BACE_1544      0
# 1510             Brc1cc(ccc1)C1CC1C=1N=C(N)N(C)C(=O)C=1  BACE_1545      0
# 1511       O=C1N(C)C(=NC(=C1)C1CC1c1cc(ccc1)-c1ccccc1)N  BACE_1546      0
# 1512                Clc1cc2nc(n(c2cc1)CCCC(=O)NCC1CC1)N  BACE_1547      0
#
#       Model     pIC50
# 0     Train  9.154901
# 1     Train  8.853872
# 2     Train  8.698970
# 3     Train  8.698970
# 4     Train  8.698970
# ...     ...       ...
# 1508   Test  3.000000
# 1509   Test  3.000000
# 1510   Test  2.953115
# 1511   Test  2.733298
# 1512   Test  2.544546
#
# [1513 rows x 5 columns]

# %%
# Visualise one of the molecules from its SMILE input
inhibitor = bace_df["mol"][0]

m = Chem.MolFromSmiles(inhibitor)

img = Draw.MolToImage(m)

display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
# Display five random molecules with their SMILES molecules

# Create axes and sample SMILES molecules
fig, ax = plt.subplots(ncols=5, nrows=1, figsize = (18,6))
mols = bace_df.sample(n=5, random_state=42)["mol"]

for i in range(len(mols)):

  # Convert each molecule to an image
  mol = mols.iloc[i]
  m = Chem.MolFromSmiles(mol)
  img = Draw.MolToImage(m)

  # Plot each molecule
  ax[i].imshow(img)
  ax[i].axis(False);

  # Divide the SMILE input into three parts
  first_part = mol[:int(len(mol)/3)]
  second_part = mol[int(len(mol)//3):int(2*len(mol)//3)]
  third_part = mol[int(2*len(mol)//3):]

  assert len(mol) == len(first_part)+len(second_part)+len(third_part)

  first_title = first_part + "\n"
  second_title = second_part + "\n"
  third_title = third_part + "\n"

  # Title each plot with its respective SMILE input
  ax[i].set_title(first_title+second_title+third_title)

# %%
# Test converting a molecule into a graph using MolGraphConvFeaturizer and to_pyg_graph

# Select first molecule
mol = bace_df["mol"][1]

# Instantiate MolGraphConvFeaturizer class
featurizer=dc.feat.MolGraphConvFeaturizer(use_edges=True)

# Convert SMILES molecule into a DeepChem graph
out = featurizer.featurize(datapoints=mol)

# Convert into torch geometric graph
pyg_out = GraphData.to_pyg_graph(out[0])
pyg_out.y = torch.tensor([bace_df["Class"][0]])

print(pyg_out)
# Out:
# Data(x=[47, 30], edge_index=[2, 100], edge_attr=[100, 11], y=[1])

# %%
# Custom torch geometric Dataset class to store the samples and their corresponding labels

class MoleculeDataset(Dataset):
  def __init__(self, root, csv_file, transform=None, pre_transform=None, pre_filter=None):
    """
    root = Where the dataset should be stored. This folder is split
    into raw_dir (downloaded dataset) and processed_dir(processed data).
    """
    self.csv_file = csv_file
    super().__init__(root, transform, pre_transform, pre_filter)

  @property
  def raw_file_names(self):
    """
    If this file exists in raw_dir, the download is not triggered/
    (the download function is not implemented here)
    """
    return self.csv_file

  @property
  def processed_file_names(self):
    """
    If these files are found in raw_dir, processing is skipped
    """
    self.data = pd.read_csv(self.raw_paths[0]).reset_index()

    return [f'data_{i}.pt' for i in list(self.data.index)]

  def download(self):
    """
    No need to download the csv file as it is already downloaded
    """
    pass

  def process(self):
    """
    I used Deepchem's MolGraphConvFeaturizer to create a graph and then convert that to a torch graph with to_pyg_graph.
    """
    self.data = pd.read_csv(self.raw_paths[0]).reset_index()
    featurizer=dc.feat.MolGraphConvFeaturizer(use_edges=True)

    for idx, row in self.data.iterrows():
      # Featurize molecule and convert to torch graph
      smiles = row['mol']
      label = row['Class']
      pic50 = row['pIC50']

      out = featurizer.featurize(smiles)
      pyg_out = GraphData.to_pyg_graph(out[0])
      pyg_out.Class = torch.tensor([label])
      pyg_out.smiles = smiles
      pyg_out.pic50 = pic50

      # data = Data(x=pyg_out.x, edge_index=pyg_out.edge_index, edge_attr=pyg_out.edge_attr,
      #            y=torch.tensor([label]), dtype = torch.float)

      torch.save(pyg_out, osp.join(self.processed_dir, f'data_{idx}.pt'))

  def len(self):
    """
    Returns number of samples in the dataset
    """
    return len(self.processed_file_names)

  def get(self, idx):
    """
    Loads a single graph
    """
    data = torch.load(osp.join(self.processed_dir, f'data_{idx}.pt'))
    return data

# %%
# Instantiate the dataset from the BACE CSV file
start_time = timer()
# original_dataset = MoleculeDataset(root = "drive/MyDrive/bace_graph_project/data/", csv_file = "bace.csv").shuffle()
original_dataset = MoleculeDataset(root = "data/", csv_file = "bace.csv").shuffle()
dataset = original_dataset
end_time = timer()
print(f"Processing dataset took {end_time-start_time:.4f}s")

train_indices = int(0.8*len(dataset))

train_dataset = dataset[:train_indices]
test_dataset = dataset[train_indices:]


print(f"Total dataset samples: {len(dataset)}\nTrain dataset samples: {len(train_dataset)}\nTest dataset samples: {len(test_dataset)}")
# Out:
# Processing...
# Done!
# Processing dataset took 19.1593s
# Total dataset samples: 1513
# Train dataset samples: 1210
# Test dataset samples: 303

# %%
# Calculate average nodes and edges in the graphs
avg_nodes = 0
avg_edges = 0
"""
for i in tqdm(range(len(original_dataset))):
  avg_nodes+=original_dataset[i].x.shape[0]
  avg_edges+=original_dataset[i].edge_index.shape[1]
avg_nodes = avg_nodes/len(original_dataset)
avg_edges = avg_edges/len(original_dataset)
print(f"avg nodes: {avg_nodes:.4f}, avg_edges: {avg_edges:.4f}")
"""
# Computation takes a long time, results:
print("avg nodes: 34.0892, avg_edges: 73.7184")
# Out:
# avg nodes: 34.0892, avg_edges: 73.7184

# %%
num_workers = 4
# Create a dataloader from the dataset
train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=num_workers)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=True, num_workers=num_workers)

print(f"Number of batches: {len(train_dataloader)}")
print(f"Number of samples: {len(train_dataset)}")
# Out:
# Number of batches: 38
# Number of samples: 1210

# %%
# Load a single graph

print(f"Number of nodes in graph is: {train_dataset[0].x.shape[0]}")
print(f"Number of features for each node is {train_dataset[0].num_features}")
print(f"Number of edges is {train_dataset[0].edge_index.shape[1]}")
print(f"Data object is {train_dataset[0]}\n")
# Out:
# Number of nodes in graph is: 33
# Number of features for each node is 30
# Number of edges is 74
# Data object is Data(x=[33, 30], edge_index=[2, 74], edge_attr=[74, 11], Class=[1], smiles='S1(=O)(=O)NCC2(N1c1cc(F)ccc1)CC([NH+](CC2)Cc1cc(OC2CCCC2)ccc1)C', pic50=4.9586072)

# %%
# Node features for one the graphs. This class is a featurizer of general graph convolution networks for molecules.
# The default node(atom) and edge(bond) representations are based on WeaveNet paper.

# train_dataset[0].x

# %%
# See the format for a batch
print(next(iter(train_dataloader)))
# Out:
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# DataBatch(x=[1097, 30], edge_index=[2, 2360], edge_attr=[2360, 11], Class=[32], smiles=[32], pic50=[32], batch=[1097], ptr=[33])

# %%
np.random.seed(44)

fig, ax = plt.subplots(ncols=2, nrows=1, figsize = (14,6))

g = torch_geometric.utils.to_networkx(train_dataset[0], to_undirected=True)
nx.draw(g, ax = ax[0])

mol = dataset[0].smiles
m = Chem.MolFromSmiles(mol)
img = Draw.MolToImage(m)

ax[1].imshow(img)
ax[1].axis(False);

# %%
# Print 5 batches
i = 0
for batch in train_dataloader:
  while i <5:
    print(i, batch)
    i+=1
# Out:
# 0 DataBatch(x=[1145, 30], edge_index=[2, 2466], edge_attr=[2466, 11], Class=[32], smiles=[32], pic50=[32], batch=[1145], ptr=[33])
# 1 DataBatch(x=[1145, 30], edge_index=[2, 2466], edge_attr=[2466, 11], Class=[32], smiles=[32], pic50=[32], batch=[1145], ptr=[33])
# 2 DataBatch(x=[1145, 30], edge_index=[2, 2466], edge_attr=[2466, 11], Class=[32], smiles=[32], pic50=[32], batch=[1145], ptr=[33])
# 3 DataBatch(x=[1145, 30], edge_index=[2, 2466], edge_attr=[2466, 11], Class=[32], smiles=[32], pic50=[32], batch=[1145], ptr=[33])
# 4 DataBatch(x=[1145, 30], edge_index=[2, 2466], edge_attr=[2466, 11], Class=[32], smiles=[32], pic50=[32], batch=[1145], ptr=[33])

# %%
start_time = timer()
for idx, batch in enumerate(train_dataloader):
  pass
end_time = timer()
print(end_time-start_time)
# Out:
# 0.5056301899999198

# %%
# Create tensor of the average of the node features for all 1210 training samples

a = torch.tensor(())
for idx, data in enumerate(train_dataloader):
  x = global_mean_pool(data.x, data.batch)
  a = torch.cat((a, x), 0)

# %%
print(a.shape)
df = pd.DataFrame(a.numpy())
# display(df)
corr = df.corr()
# corr.style.background_gradient(cmap='coolwarm')
# Out:
# torch.Size([1210, 30])

# %%
class GCNClassifier(torch.nn.Module):
  """
  Standard GCN graph classifier
  """
  def __init__(self, in_channels:int, hidden_channels:int, out_channels:int, pool_method:torch_geometric.nn.pool):
    super().__init__()
    # Convolutional Layers
    self.conv1 = GCNConv(in_channels, hidden_channels)

    self.conv2 = GCNConv(hidden_channels, hidden_channels)

    self.conv3 = GCNConv(hidden_channels, hidden_channels)

    # Linear layer used in classification
    self.lin = Linear(hidden_channels, out_channels)

  def forward(self, data):
    # Obtain node embeddings
    x, edge_index, batch, edge_attr = data.x, data.edge_index, data.batch, data.edge_attr

    x = self.conv1(x, edge_index)
    x = F.leaky_relu(x)
    x = self.conv2(x, edge_index)
    x = F.leaky_relu(x)
    x = self.conv3(x, edge_index)

    # Aggregate node embeddings
    x = pool_method(x, batch)

    # Regularisation
    x = F.dropout(x)

    # Classification
    x = self.lin(x)

    x = F.softmax(x, dim=1)

    return x

GCNClassifier(7, 64, 2, global_mean_pool)
# Out:
# GCNClassifier(
#   (conv1): GCNConv(7, 64)
#   (conv2): GCNConv(64, 64)
#   (conv3): GCNConv(64, 64)
#   (lin): Linear(in_features=64, out_features=2, bias=True)
# )

# %%
class GraphConvClassifier(GCNClassifier):
  """
  Same architecture as GCN Classifier however use GraphConv layers
  """
  def __init__(self, in_channels:int, hidden_channels:int, out_channels:int,  pool_method:torch_geometric.nn.pool):
    super().__init__(in_channels, hidden_channels, out_channels, pool_method)
    self.conv1 = GraphConv(in_channels, hidden_channels)

    self.conv2 = GraphConv(hidden_channels, hidden_channels)

    self.conv3 = GraphConv(hidden_channels, hidden_channels)
GraphConvClassifier(7, 64, 2, global_mean_pool)
# Out:
# GraphConvClassifier(
#   (conv1): GraphConv(7, 64)
#   (conv2): GraphConv(64, 64)
#   (conv3): GraphConv(64, 64)
#   (lin): Linear(in_features=64, out_features=2, bias=True)
# )

# %%
class GATClassifier(torch.nn.Module):
  """
  GAT Convolutional graph classifier
  """
  def __init__(self, in_channels:int, hidden_channels:int, out_channels:int, heads:int, pool_method:torch_geometric.nn.pool,
               use_edge_attr:bool):
    super().__init__()
    # Convolutional Layers
    self.conv1 = GATConv(in_channels,
                         hidden_channels,
                         heads,
                         concat = True)
    self.conv2 = GATConv(hidden_channels*heads,
                         hidden_channels,
                         heads,
                         concat=True)
    self.conv3 = GATConv(hidden_channels*heads,
                         hidden_channels,
                         1,
                         concat=False)
    self.lin = Linear(hidden_channels, out_channels)

  def forward(self, data):
    # Obtain node embeddings
    x, edge_index, batch, edge_attr = data.x, data.edge_index, data.batch, data.edge_attr

    # can use edge attributes
    if use_edge_attr:
      x = self.conv1(x, edge_index, edge_attr)
      x = F.leaky_relu(x)
      x = self.conv2(x, edge_index, edge_attr)
      x = F.leaky_relu(x)
      x = self.conv3(x, edge_index, edge_attr)

    # not using edge attributes
    else:
      x = self.conv1(x, edge_index)
      x = F.leaky_relu(x)
      x = self.conv2(x, edge_index)
      x = F.leaky_relu(x)
      x = self.conv3(x, edge_index)

    # Aggregate node embeddings
    x = pool_method(x, batch)

    # Regularisation
    x = F.dropout(x)

    # Classification
    x = self.lin(x)

    x = F.softmax(x, dim=1)

    return x

GATClassifier(30, 64, 2, 8, global_max_pool, True)
# Out:
# GATClassifier(
#   (conv1): GATConv(30, 64, heads=8)
#   (conv2): GATConv(512, 64, heads=8)
#   (conv3): GATConv(512, 64, heads=1)
#   (lin): Linear(in_features=64, out_features=2, bias=True)
# )

# %%
type(GINConv(nn))
# Out:
# torch_geometric.nn.conv.gin_conv.GINConv

# %%
class GINConvClassifier(torch.nn.Module):
  """
  Applies the graph isomorphism operator
  """
  def __init__(self, in_channels, hidden_channels, out_channels, num_layers, pool_method: torch_geometric.nn.pool):
    super().__init__()

    self.convs = torch.nn.ModuleList()
    self.conv = GINConv

    for _ in range(num_layers):
      mlp = MLP([in_channels, hidden_channels, hidden_channels])
      self.convs.append(self.conv(nn=mlp, train_eps=False))
      in_channels = hidden_channels

    self.mlp = MLP([hidden_channels, hidden_channels, out_channels], norm = None, dropout = 0.5)

  def forward(self, data):
    x, edge_index, batch = data.x, data.edge_index, data.batch
    for conv in self.convs:
      x = conv(x, edge_index).relu()
    x = pool_method(x, batch)
    return self.mlp(x)

GINConvClassifier(30, 64, 2, 3, global_mean_pool)
# Out:
# GINConvClassifier(
#   (convs): ModuleList(
#     (0): GINConv(nn=MLP(30, 64, 64))
#     (1-2): 2 x GINConv(nn=MLP(64, 64, 64))
#   )
#   (mlp): MLP(64, 64, 2)
# )

# %%
class GINEConvClassifier(torch.nn.Module):
  """
  Applies the graph isomorphism operator
  """
  def __init__(self, in_channels, hidden_channels, out_channels, num_layers, pool_method: torch_geometric.nn.pool,
               use_edge_attr:bool, edge_dim:int):
    super().__init__()

    self.convs = torch.nn.ModuleList()
    self.conv = GINEConv
    self.use_edge_attr = use_edge_attr
    self.edge_dim = edge_dim

    for _ in range(num_layers):
      mlp = MLP([in_channels, hidden_channels, hidden_channels])
      self.convs.append(self.conv(nn=mlp, train_eps=False, edge_dim=self.edge_dim))
      in_channels = hidden_channels

    self.mlp = MLP([hidden_channels, hidden_channels, out_channels], norm = None, dropout = 0.5)

  def forward(self, data):
    x, edge_index, batch, edge_attr = data.x, data.edge_index, data.batch, data.edge_attr
    for conv in self.convs:
      if self.use_edge_attr:
        x = conv(x, edge_index, edge_attr).relu()
      else:
        x = conv(x, edge_index).relu()

    x = pool_method(x, batch)
    return self.mlp(x)

GINEConvClassifier(30, 64, 2, 3, global_mean_pool, True, dataset[0].edge_attr.shape[1])
# Out:
# GINEConvClassifier(
#   (convs): ModuleList(
#     (0): GINEConv(nn=MLP(30, 64, 64))
#     (1-2): 2 x GINEConv(nn=MLP(64, 64, 64))
#   )
#   (mlp): MLP(64, 64, 2)
# )

# %%
dataset[2].edge_attr.shape[1]
# Out:
# 11

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
auroc_metric = BinaryAUROC(thresholds=100).to(device)

def train_step(model:torch.nn.Module,
               dataloader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer):

  # Send model to device

  model.to(device)
  model.train()


  train_loss, train_acc, train_auc = 0, 0, 0


  auc_time = 0
  out_time = 0
  loss_time = 0
  optimizer_time = 0
  section_time = 0
  dataloader_loop_time = 0
  inside_loop_time = 0


  loop_start_time = timer()
  # Loop over the batches
  for idx, batch in enumerate(dataloader):
    # print(f"entered {idx} loop of train step")
    inside_loop_start_time = timer()
    if idx > 1:
      dataloader_loop_end_time = timer()
      dataloader_loop_time += dataloader_loop_end_time-dataloader_loop_start_time

    section_start_time = timer()
    to_device_start_time = timer()
    batch = batch.to(device)
    to_device_end_time = timer()

    # Optimizer zero grad
    optimizer.zero_grad()


    # Forward pass
    out_start_time = timer()
    out = model(batch)
    out_end_time = timer()
    out_time+=out_end_time-out_start_time


    # Calculate the loss
    loss = loss_fn(out, batch.Class)
    train_loss += loss.item()

    # Calculate the label predictions
    label_preds = torch.argmax(out, dim=1)
    # Calculate accuracy
    train_acc += (label_preds == batch.Class).sum()

    # Calculate the AUC
    auc_start_time = timer()
    train_auc += auroc_metric(out[:,1], batch.Class).item()
    # print(len(auroc_metric.thresholds))
    # train_auc += 0.03
    auc_end_time = timer()
    auc_time += auc_end_time-auc_start_time

    # Loss backward
    loss_start_time = timer()
    loss.backward()
    loss_end_time = timer()
    loss_time += loss_end_time-loss_start_time

    # Optimizer step
    optimizer_start_time = timer()
    optimizer.step()
    optimizer_end_time = timer()
    optimizer_time = optimizer_end_time-optimizer_start_time
    section_end_time = timer()
    section_time+=section_end_time-section_start_time
    dataloader_loop_start_time = timer()
    inside_loop_end_time = timer()
    inside_loop_time += inside_loop_end_time-inside_loop_start_time


  loop_end_time = timer()
  # print(f"Section time is {section_time:.4f}")
  # print(f"Dataloader loop time is {dataloader_loop_time:.4f}")

  # Adjust metrics to get average loss and accuracy per batch
  train_loss = train_loss/len(dataloader.dataset)
  train_acc = train_acc/len(dataloader.dataset)
  train_auc = train_auc/len(dataloader)
  # print(f"AUC calculation time: {auc_time:.4f}s, Forward pass: {out_time:.4f}s, Loss time: {loss_time:.4f}, Optimizer time: {optimizer_time:.4f}, To device time: {to_device_end_time-to_device_start_time:.4f}\n")


  #print(f"Train outside loop time is {loop_end_time-loop_start_time:.4f}, inside loop time is {inside_loop_time:.4f}")

  return train_loss, train_acc, train_auc

# %%
def test_step(model:torch.nn.Module,
               dataloader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer):
  # Put model in eval mode
  model.eval()

  test_loss, test_acc, test_auc = 0, 0, 0

  # Turn on torch inference manager
  with torch.inference_mode():
    # Loop through data batches
    for idx, batch in enumerate(dataloader):
      # print(f"entered test step {idx} batch loop")
      batch = batch.to(device)

      # Forward pass
      out = model(batch)

      # Calculate the loss
      loss = loss_fn(out, batch.Class)
      test_loss += loss.item()

      # Calculate the label predictions
      label_preds = torch.argmax(out, dim=1)
      # Calculate accuracy
      test_acc += (label_preds == batch.Class).sum()/len(label_preds)

      # Calculate the AUC
      test_auc += auroc_metric(out[:,1], batch.Class).item()

    # Adjust metrics to get average loss and accuracy per batch
    test_loss = test_loss/len(dataloader)
    test_acc = test_acc/len(dataloader)
    test_auc = test_auc/len(dataloader)

    return test_loss, test_acc, test_auc

# %%
# Take in various parameters required for training and test steps
def train(model: torch.nn.Module,
          train_dataloader: torch.utils.data.DataLoader,
          test_dataloader: torch.utils.data.DataLoader,
          optimizer: torch.optim.Optimizer,
          loss_fn: torch.nn.Module = torch.nn.CrossEntropyLoss(),
          epochs: int =5,
          model_save_path: str = None):


  # 2. Create empty results dictionary
  results = {"epoch": [],
             "train_loss": [],
             "train_acc": [],
             "train_auc": [],
             "test_loss": [],
             "test_acc": [],
             "test_auc": [],
             "saved_model_epoch": 0}
  # 3. Loop through training and testing steps for a number of epochs
  for i in tqdm(range(epochs)):
    start_time = timer()
    train_step_start_time = timer()
    train_loss, train_acc, train_auc = train_step(model,
                                       train_dataloader,
                                       loss_fn,
                                       optimizer)
    train_step_end_time = timer()
    test_step_start_time = timer()
    test_loss, test_acc, test_auc = test_step(model,
                                    test_dataloader,
                                    loss_fn,
                                    optimizer)
    test_step_end_time = timer()
    # print(f"Train step time is {train_step_end_time-train_step_start_time:.4f}s, Test step time is {test_step_end_time-test_step_start_time:.4f}s\n")

    # 4. Print out what's happening
    print(f"Epoch: {i}, Train loss: {train_loss:.4f}, Train acc: {train_acc:.4f}, Train AUC: {train_auc:.4f}, Test loss: {test_loss:.4f}, Test acc: {test_acc:.4f}, Test auc: {test_auc:.4f}")
    # 5. Update results dictionary
    append_start_time = timer()
    results["epoch"].append(i)
    results["train_loss"].append(round(train_loss, 4))
    results["train_acc"].append(round(train_acc.item(), 4))
    results["train_auc"].append(round(train_auc, 4))
    results["test_loss"].append(round(test_loss, 4))
    results["test_acc"].append(round(test_acc.item(), 4))
    results["test_auc"].append(round(test_auc, 4))
    append_end_time = timer()
    # print(f"append time is{append_end_time-append_start_time:.4f}")

    # 6. If model_save_path provided, save the model to its path
    if model_save_path:
      save_start_time = timer()
      if i > 5 and results["test_loss"][-1] < np.mean(results["test_loss"][-5:-1]) and results["test_auc"][-1] > np.mean(results["test_auc"][-5:-1]):
        print(f"Saving model to: {model_save_path}")
        results["saved_model_epoch"] = i
        torch.save(obj=model.state_dict(), # only saving the state_dict() only saves the models learned parameters
                    f=model_save_path)
      save_end_time = timer()
      # print(f"Saving time took {save_end_time-save_start_time:.4f} seconds")
      end_time  = timer()
      print(f"Epoch took {end_time-start_time:.2f} seconds")
  print(f"Saved model epoch is {results['saved_model_epoch']}")

  # 7. Return the filled results at the end of the epochs

  return results

# %%
# Create model directory in drive to save models into
print(f"bace_project path: {bace_project_path}")
bace_models_path = bace_project_path / "models"
print(f"bace_models_path: {bace_models_path}\n")

if bace_models_path.is_dir():
  print(f"{bace_models_path} is already a directory")
else:
  print(f"{bace_models_path} is not a directory, creating one")
  bace_models_path.mkdir(parents=True, exist_ok=True)
# Out:
# bace_project path: drive/MyDrive/bace_graph_project
# bace_models_path: drive/MyDrive/bace_graph_project/models
#
# drive/MyDrive/bace_graph_project/models is already a directory

# %%
# GCN Classifier Training Run

display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 300})'''))

torch.manual_seed(42)

# Number of features of the graphs
num_features = next(iter(train_dataloader)).x.shape[1]
num_hidden_channels = 128
num_out_channels = 2
# with global mean pooling, best is around 100 epochs
nb_epochs = 250
pool_method = global_mean_pool

# Instantiating GCN Classifier
model = GCNClassifier(num_features, num_hidden_channels, num_out_channels, pool_method)

# Instantiate optimizer and loss function
adam_optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
sgd_optimizer = torch.optim.SGD(model.parameters())
criterion = torch.nn.CrossEntropyLoss()



bace_gcn_models_path = bace_models_path / "gcn_models"


if bace_gcn_models_path.is_dir():
  print(f"{bace_gcn_models_path} is already a directory")
else:
  print(f"{bace_gcn_models_path} is not a directory, creating one")
  bace_gcn_models_path.mkdir(parents=True, exist_ok=True)


for i in range(1):
  model_save_name = f"{i}_{num_hidden_channels}_{nb_epochs}_{pool_method.__name__}.pth"
  model_save_path  = bace_gcn_models_path / model_save_name
  results = train(model,
      train_dataloader,
      test_dataloader,
      adam_optimizer,
      loss_fn = criterion,
      epochs = nb_epochs,
      model_save_path = model_save_path)
  with open(bace_gcn_models_path/f"{i}_{num_hidden_channels}_{nb_epochs}_{pool_method.__name__}_results.pkl", 'wb') as f:
    print("entered with open pickle")
    pickle.dump(results, f)



"""
results = train(model,
      train_dataloader,
      test_dataloader,
      adam_optimizer,
      loss_fn = criterion,
      epochs = nb_epochs)
"""
# Out:
# drive/MyDrive/bace_graph_project/models/gcn_models is already a directory
#   0%|          | 0/250 [00:00<?, ?it/s]
# Epoch: 0, Train loss: 0.0216, Train acc: 0.5372, Train AUC: 0.5370, Test loss: 0.6842, Test acc: 0.5556, Test auc: 0.5451
# Epoch took 1.10 seconds
# Epoch: 1, Train loss: 0.0216, Train acc: 0.5380, Train AUC: 0.5607, Test loss: 0.6799, Test acc: 0.5560, Test auc: 0.5828
# Epoch took 1.06 seconds
# Epoch: 2, Train loss: 0.0214, Train acc: 0.5645, Train AUC: 0.5919, Test loss: 0.6706, Test acc: 0.5702, Test auc: 0.6026
# Epoch took 1.05 seconds
# Epoch: 3, Train loss: 0.0211, Train acc: 0.5694, Train AUC: 0.6330, Test loss: 0.6605, Test acc: 0.5904, Test auc: 0.6385
# Epoch took 1.10 seconds
# Epoch: 4, Train loss: 0.0207, Train acc: 0.6058, Train AUC: 0.6533, Test loss: 0.6519, Test acc: 0.6221, Test auc: 0.6630
# Epoch took 1.07 seconds
# Epoch: 5, Train loss: 0.0206, Train acc: 0.6116, Train AUC: 0.6817, Test loss: 0.6407, Test acc: 0.6456, Test auc: 0.6962
# Epoch took 1.06 seconds
# Epoch: 6, Train loss: 0.0204, Train acc: 0.6140, Train AUC: 0.6929, Test loss: 0.6284, Test acc: 0.6546, Test auc: 0.7157
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.09 seconds
# Epoch: 7, Train loss: 0.0202, Train acc: 0.6240, Train AUC: 0.7016, Test loss: 0.6253, Test acc: 0.6800, Test auc: 0.7348
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.11 seconds
# Epoch: 8, Train loss: 0.0201, Train acc: 0.6380, Train AUC: 0.7137, Test loss: 0.6229, Test acc: 0.6733, Test auc: 0.7212
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.17 seconds
# Epoch: 9, Train loss: 0.0201, Train acc: 0.6397, Train AUC: 0.7172, Test loss: 0.6357, Test acc: 0.6448, Test auc: 0.7433
# Epoch took 1.15 seconds
# Epoch: 10, Train loss: 0.0197, Train acc: 0.6537, Train AUC: 0.7268, Test loss: 0.6173, Test acc: 0.6721, Test auc: 0.7473
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.12 seconds
# Epoch: 11, Train loss: 0.0196, Train acc: 0.6653, Train AUC: 0.7402, Test loss: 0.6086, Test acc: 0.6667, Test auc: 0.7347
# Epoch took 1.07 seconds
# Epoch: 12, Train loss: 0.0193, Train acc: 0.6736, Train AUC: 0.7445, Test loss: 0.6210, Test acc: 0.6840, Test auc: 0.7603
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.06 seconds
# Epoch: 13, Train loss: 0.0194, Train acc: 0.6744, Train AUC: 0.7433, Test loss: 0.5994, Test acc: 0.6640, Test auc: 0.7696
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.09 seconds
# Epoch: 14, Train loss: 0.0191, Train acc: 0.6901, Train AUC: 0.7514, Test loss: 0.6001, Test acc: 0.6715, Test auc: 0.7551
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.07 seconds
# Epoch: 15, Train loss: 0.0193, Train acc: 0.6777, Train AUC: 0.7503, Test loss: 0.6051, Test acc: 0.7015, Test auc: 0.7806
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.06 seconds
# Epoch: 16, Train loss: 0.0190, Train acc: 0.6884, Train AUC: 0.7625, Test loss: 0.5806, Test acc: 0.7019, Test auc: 0.7898
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.06 seconds
# Epoch: 17, Train loss: 0.0189, Train acc: 0.6860, Train AUC: 0.7647, Test loss: 0.5925, Test acc: 0.6929, Test auc: 0.7982
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.12 seconds
# Epoch: 18, Train loss: 0.0186, Train acc: 0.6992, Train AUC: 0.7712, Test loss: 0.5802, Test acc: 0.6948, Test auc: 0.7869
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.11 seconds
# Epoch: 19, Train loss: 0.0185, Train acc: 0.7074, Train AUC: 0.7713, Test loss: 0.6065, Test acc: 0.6948, Test auc: 0.7809
# Epoch took 1.12 seconds
# Epoch: 20, Train loss: 0.0187, Train acc: 0.6901, Train AUC: 0.7727, Test loss: 0.5948, Test acc: 0.7054, Test auc: 0.8000
# Epoch took 1.15 seconds
# Epoch: 21, Train loss: 0.0183, Train acc: 0.7215, Train AUC: 0.7909, Test loss: 0.5767, Test acc: 0.7104, Test auc: 0.7977
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.16 seconds
# Epoch: 22, Train loss: 0.0181, Train acc: 0.7198, Train AUC: 0.7944, Test loss: 0.5707, Test acc: 0.7210, Test auc: 0.8036
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.09 seconds
# Epoch: 23, Train loss: 0.0180, Train acc: 0.7347, Train AUC: 0.7843, Test loss: 0.5607, Test acc: 0.7546, Test auc: 0.8123
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.13 seconds
# Epoch: 24, Train loss: 0.0184, Train acc: 0.7149, Train AUC: 0.7855, Test loss: 0.5782, Test acc: 0.6913, Test auc: 0.7872
# Epoch took 1.09 seconds
# Epoch: 25, Train loss: 0.0182, Train acc: 0.7207, Train AUC: 0.7871, Test loss: 0.5635, Test acc: 0.7358, Test auc: 0.8107
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.08 seconds
# Epoch: 26, Train loss: 0.0178, Train acc: 0.7331, Train AUC: 0.7995, Test loss: 0.5836, Test acc: 0.7117, Test auc: 0.7992
# Epoch took 1.09 seconds
# Epoch: 27, Train loss: 0.0179, Train acc: 0.7347, Train AUC: 0.8006, Test loss: 0.5532, Test acc: 0.7585, Test auc: 0.8317
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.09 seconds
# Epoch: 28, Train loss: 0.0176, Train acc: 0.7322, Train AUC: 0.8098, Test loss: 0.5496, Test acc: 0.7546, Test auc: 0.8359
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.08 seconds
# Epoch: 29, Train loss: 0.0176, Train acc: 0.7405, Train AUC: 0.8064, Test loss: 0.5647, Test acc: 0.7350, Test auc: 0.8254
# Epoch took 1.07 seconds
# Epoch: 30, Train loss: 0.0175, Train acc: 0.7471, Train AUC: 0.8078, Test loss: 0.5644, Test acc: 0.7198, Test auc: 0.8249
# Epoch took 1.08 seconds
# Epoch: 31, Train loss: 0.0176, Train acc: 0.7488, Train AUC: 0.8156, Test loss: 0.5561, Test acc: 0.7542, Test auc: 0.8108
# Epoch took 1.16 seconds
# Epoch: 32, Train loss: 0.0175, Train acc: 0.7463, Train AUC: 0.8160, Test loss: 0.5552, Test acc: 0.7483, Test auc: 0.8169
# Epoch took 1.17 seconds
# Epoch: 33, Train loss: 0.0173, Train acc: 0.7562, Train AUC: 0.8158, Test loss: 0.5728, Test acc: 0.7417, Test auc: 0.8282
# Epoch took 1.08 seconds
# Epoch: 34, Train loss: 0.0178, Train acc: 0.7289, Train AUC: 0.8154, Test loss: 0.5461, Test acc: 0.7604, Test auc: 0.8308
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.10 seconds
# Epoch: 35, Train loss: 0.0172, Train acc: 0.7595, Train AUC: 0.8109, Test loss: 0.5486, Test acc: 0.7581, Test auc: 0.8177
# Epoch took 1.09 seconds
# Epoch: 36, Train loss: 0.0172, Train acc: 0.7562, Train AUC: 0.8141, Test loss: 0.5347, Test acc: 0.7715, Test auc: 0.8375
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.07 seconds
# Epoch: 37, Train loss: 0.0179, Train acc: 0.7289, Train AUC: 0.8248, Test loss: 0.6322, Test acc: 0.6475, Test auc: 0.8278
# Epoch took 1.09 seconds
# Epoch: 38, Train loss: 0.0173, Train acc: 0.7496, Train AUC: 0.8227, Test loss: 0.5224, Test acc: 0.7937, Test auc: 0.8469
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.08 seconds
# Epoch: 39, Train loss: 0.0170, Train acc: 0.7694, Train AUC: 0.8228, Test loss: 0.5257, Test acc: 0.7773, Test auc: 0.8374
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.07 seconds
# Epoch: 40, Train loss: 0.0169, Train acc: 0.7620, Train AUC: 0.8315, Test loss: 0.5316, Test acc: 0.7644, Test auc: 0.8448
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.14 seconds
# Epoch: 41, Train loss: 0.0171, Train acc: 0.7504, Train AUC: 0.8363, Test loss: 0.5656, Test acc: 0.7238, Test auc: 0.8246
# Epoch took 1.05 seconds
# Epoch: 42, Train loss: 0.0167, Train acc: 0.7727, Train AUC: 0.8272, Test loss: 0.5313, Test acc: 0.7573, Test auc: 0.8484
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.11 seconds
# Epoch: 43, Train loss: 0.0167, Train acc: 0.7777, Train AUC: 0.8274, Test loss: 0.5341, Test acc: 0.7671, Test auc: 0.8447
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.13 seconds
# Epoch: 44, Train loss: 0.0170, Train acc: 0.7579, Train AUC: 0.8275, Test loss: 0.5484, Test acc: 0.7604, Test auc: 0.8382
# Epoch took 1.16 seconds
# Epoch: 45, Train loss: 0.0167, Train acc: 0.7694, Train AUC: 0.8330, Test loss: 0.5424, Test acc: 0.7608, Test auc: 0.8354
# Epoch took 1.05 seconds
# Epoch: 46, Train loss: 0.0167, Train acc: 0.7711, Train AUC: 0.8362, Test loss: 0.5200, Test acc: 0.7898, Test auc: 0.8425
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.10 seconds
# Epoch: 47, Train loss: 0.0164, Train acc: 0.7851, Train AUC: 0.8412, Test loss: 0.5357, Test acc: 0.7690, Test auc: 0.8442
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.09 seconds
# Epoch: 48, Train loss: 0.0167, Train acc: 0.7694, Train AUC: 0.8399, Test loss: 0.5118, Test acc: 0.7965, Test auc: 0.8629
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.08 seconds
# Epoch: 49, Train loss: 0.0165, Train acc: 0.7810, Train AUC: 0.8403, Test loss: 0.5244, Test acc: 0.7746, Test auc: 0.8539
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.06 seconds
# Epoch: 50, Train loss: 0.0165, Train acc: 0.7818, Train AUC: 0.8343, Test loss: 0.5207, Test acc: 0.7863, Test auc: 0.8613
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.11 seconds
# Epoch: 51, Train loss: 0.0162, Train acc: 0.7975, Train AUC: 0.8404, Test loss: 0.5214, Test acc: 0.7890, Test auc: 0.8621
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.11 seconds
# Epoch: 52, Train loss: 0.0164, Train acc: 0.7860, Train AUC: 0.8414, Test loss: 0.5221, Test acc: 0.7858, Test auc: 0.8371
# Epoch took 1.09 seconds
# Epoch: 53, Train loss: 0.0162, Train acc: 0.7959, Train AUC: 0.8404, Test loss: 0.5299, Test acc: 0.7796, Test auc: 0.8659
# Epoch took 1.14 seconds
# Epoch: 54, Train loss: 0.0164, Train acc: 0.7785, Train AUC: 0.8431, Test loss: 0.5149, Test acc: 0.7929, Test auc: 0.8625
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.19 seconds
# Epoch: 55, Train loss: 0.0165, Train acc: 0.7818, Train AUC: 0.8404, Test loss: 0.5600, Test acc: 0.7546, Test auc: 0.8397
# Epoch took 1.10 seconds
# Epoch: 56, Train loss: 0.0167, Train acc: 0.7793, Train AUC: 0.8303, Test loss: 0.5290, Test acc: 0.7827, Test auc: 0.8421
# Epoch took 1.09 seconds
# Epoch: 57, Train loss: 0.0161, Train acc: 0.7950, Train AUC: 0.8407, Test loss: 0.5142, Test acc: 0.8019, Test auc: 0.8589
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.11 seconds
# Epoch: 58, Train loss: 0.0161, Train acc: 0.7983, Train AUC: 0.8470, Test loss: 0.5186, Test acc: 0.7894, Test auc: 0.8472
# Epoch took 1.10 seconds
# Epoch: 59, Train loss: 0.0167, Train acc: 0.7727, Train AUC: 0.8476, Test loss: 0.5557, Test acc: 0.7412, Test auc: 0.8324
# Epoch took 1.10 seconds
# Epoch: 60, Train loss: 0.0165, Train acc: 0.7760, Train AUC: 0.8326, Test loss: 0.5313, Test acc: 0.7690, Test auc: 0.8287
# Epoch took 1.06 seconds
# Epoch: 61, Train loss: 0.0161, Train acc: 0.8008, Train AUC: 0.8451, Test loss: 0.5258, Test acc: 0.7756, Test auc: 0.8429
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.05 seconds
# Epoch: 62, Train loss: 0.0161, Train acc: 0.7950, Train AUC: 0.8476, Test loss: 0.5067, Test acc: 0.8031, Test auc: 0.8610
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.14 seconds
# Epoch: 63, Train loss: 0.0161, Train acc: 0.7884, Train AUC: 0.8522, Test loss: 0.5110, Test acc: 0.7831, Test auc: 0.8470
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.12 seconds
# Epoch: 64, Train loss: 0.0165, Train acc: 0.7769, Train AUC: 0.8455, Test loss: 0.5143, Test acc: 0.7894, Test auc: 0.8579
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.13 seconds
# Epoch: 65, Train loss: 0.0159, Train acc: 0.8033, Train AUC: 0.8507, Test loss: 0.5187, Test acc: 0.7898, Test auc: 0.8646
# Epoch took 1.15 seconds
# Epoch: 66, Train loss: 0.0159, Train acc: 0.7992, Train AUC: 0.8516, Test loss: 0.5205, Test acc: 0.7956, Test auc: 0.8475
# Epoch took 1.14 seconds
# Epoch: 67, Train loss: 0.0161, Train acc: 0.7917, Train AUC: 0.8543, Test loss: 0.5158, Test acc: 0.7921, Test auc: 0.8587
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.09 seconds
# Epoch: 68, Train loss: 0.0167, Train acc: 0.7694, Train AUC: 0.8509, Test loss: 0.5360, Test acc: 0.7667, Test auc: 0.8381
# Epoch took 1.10 seconds
# Epoch: 69, Train loss: 0.0161, Train acc: 0.7901, Train AUC: 0.8470, Test loss: 0.5144, Test acc: 0.7952, Test auc: 0.8520
# Epoch took 1.11 seconds
# Epoch: 70, Train loss: 0.0159, Train acc: 0.8058, Train AUC: 0.8521, Test loss: 0.5101, Test acc: 0.7929, Test auc: 0.8444
# Epoch took 1.13 seconds
# Epoch: 71, Train loss: 0.0165, Train acc: 0.7727, Train AUC: 0.8415, Test loss: 0.5303, Test acc: 0.7863, Test auc: 0.8446
# Epoch took 1.11 seconds
# Epoch: 72, Train loss: 0.0161, Train acc: 0.7934, Train AUC: 0.8458, Test loss: 0.5169, Test acc: 0.7819, Test auc: 0.8426
# Epoch took 1.10 seconds
# Epoch: 73, Train loss: 0.0164, Train acc: 0.7802, Train AUC: 0.8514, Test loss: 0.5202, Test acc: 0.7925, Test auc: 0.8515
# Epoch took 1.08 seconds
# Epoch: 74, Train loss: 0.0163, Train acc: 0.7860, Train AUC: 0.8400, Test loss: 0.5566, Test acc: 0.7596, Test auc: 0.8402
# Epoch took 1.12 seconds
# Epoch: 75, Train loss: 0.0159, Train acc: 0.8008, Train AUC: 0.8561, Test loss: 0.5078, Test acc: 0.7992, Test auc: 0.8553
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.12 seconds
# Epoch: 76, Train loss: 0.0162, Train acc: 0.7942, Train AUC: 0.8464, Test loss: 0.5335, Test acc: 0.7823, Test auc: 0.8300
# Epoch took 1.16 seconds
# Epoch: 77, Train loss: 0.0159, Train acc: 0.8000, Train AUC: 0.8489, Test loss: 0.5348, Test acc: 0.7644, Test auc: 0.8501
# Epoch took 1.21 seconds
# Epoch: 78, Train loss: 0.0158, Train acc: 0.8066, Train AUC: 0.8503, Test loss: 0.5270, Test acc: 0.7858, Test auc: 0.8478
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.07 seconds
# Epoch: 79, Train loss: 0.0157, Train acc: 0.8116, Train AUC: 0.8527, Test loss: 0.5297, Test acc: 0.7644, Test auc: 0.8427
# Epoch took 1.09 seconds
# Epoch: 80, Train loss: 0.0158, Train acc: 0.8066, Train AUC: 0.8522, Test loss: 0.5396, Test acc: 0.7671, Test auc: 0.8487
# Epoch took 1.07 seconds
# Epoch: 81, Train loss: 0.0160, Train acc: 0.8025, Train AUC: 0.8547, Test loss: 0.5208, Test acc: 0.7877, Test auc: 0.8327
# Epoch took 1.05 seconds
# Epoch: 82, Train loss: 0.0158, Train acc: 0.8058, Train AUC: 0.8444, Test loss: 0.5063, Test acc: 0.7960, Test auc: 0.8582
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.10 seconds
# Epoch: 83, Train loss: 0.0158, Train acc: 0.7983, Train AUC: 0.8552, Test loss: 0.5126, Test acc: 0.7867, Test auc: 0.8431
# Epoch took 1.09 seconds
# Epoch: 84, Train loss: 0.0158, Train acc: 0.7967, Train AUC: 0.8512, Test loss: 0.5296, Test acc: 0.7663, Test auc: 0.8413
# Epoch took 1.10 seconds
# Epoch: 85, Train loss: 0.0160, Train acc: 0.8017, Train AUC: 0.8551, Test loss: 0.5205, Test acc: 0.7756, Test auc: 0.8295
# Epoch took 1.08 seconds
# Epoch: 86, Train loss: 0.0159, Train acc: 0.7983, Train AUC: 0.8599, Test loss: 0.5365, Test acc: 0.7644, Test auc: 0.8667
# Epoch took 1.06 seconds
# Epoch: 87, Train loss: 0.0160, Train acc: 0.7983, Train AUC: 0.8577, Test loss: 0.5099, Test acc: 0.7925, Test auc: 0.8587
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.13 seconds
# Epoch: 88, Train loss: 0.0157, Train acc: 0.8149, Train AUC: 0.8643, Test loss: 0.5099, Test acc: 0.7983, Test auc: 0.8468
# Epoch took 1.17 seconds
# Epoch: 89, Train loss: 0.0161, Train acc: 0.7917, Train AUC: 0.8494, Test loss: 0.5148, Test acc: 0.7756, Test auc: 0.8312
# Epoch took 1.07 seconds
# Epoch: 90, Train loss: 0.0162, Train acc: 0.7909, Train AUC: 0.8550, Test loss: 0.5134, Test acc: 0.7956, Test auc: 0.8428
# Epoch took 1.08 seconds
# Epoch: 91, Train loss: 0.0159, Train acc: 0.7992, Train AUC: 0.8508, Test loss: 0.5049, Test acc: 0.8046, Test auc: 0.8500
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.10 seconds
# Epoch: 92, Train loss: 0.0157, Train acc: 0.8074, Train AUC: 0.8486, Test loss: 0.5296, Test acc: 0.7765, Test auc: 0.8606
# Epoch took 1.09 seconds
# Epoch: 93, Train loss: 0.0155, Train acc: 0.8140, Train AUC: 0.8559, Test loss: 0.5111, Test acc: 0.7960, Test auc: 0.8472
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.12 seconds
# Epoch: 94, Train loss: 0.0156, Train acc: 0.8124, Train AUC: 0.8635, Test loss: 0.5067, Test acc: 0.8019, Test auc: 0.8553
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.09 seconds
# Epoch: 95, Train loss: 0.0161, Train acc: 0.8000, Train AUC: 0.8527, Test loss: 0.5076, Test acc: 0.8019, Test auc: 0.8598
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.10 seconds
# Epoch: 96, Train loss: 0.0157, Train acc: 0.8132, Train AUC: 0.8633, Test loss: 0.5066, Test acc: 0.8031, Test auc: 0.8620
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.08 seconds
# Epoch: 97, Train loss: 0.0155, Train acc: 0.8207, Train AUC: 0.8584, Test loss: 0.5299, Test acc: 0.7858, Test auc: 0.8409
# Epoch took 1.10 seconds
# Epoch: 98, Train loss: 0.0159, Train acc: 0.8000, Train AUC: 0.8625, Test loss: 0.5080, Test acc: 0.8010, Test auc: 0.8521
# Epoch took 1.14 seconds
# Epoch: 99, Train loss: 0.0156, Train acc: 0.8124, Train AUC: 0.8566, Test loss: 0.5085, Test acc: 0.8058, Test auc: 0.8605
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.16 seconds
# Epoch: 100, Train loss: 0.0157, Train acc: 0.8033, Train AUC: 0.8575, Test loss: 0.5024, Test acc: 0.8113, Test auc: 0.8481
# Epoch took 1.12 seconds
# Epoch: 101, Train loss: 0.0155, Train acc: 0.8165, Train AUC: 0.8565, Test loss: 0.5087, Test acc: 0.7988, Test auc: 0.8523
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.06 seconds
# Epoch: 102, Train loss: 0.0155, Train acc: 0.8157, Train AUC: 0.8629, Test loss: 0.5144, Test acc: 0.7796, Test auc: 0.8556
# Epoch took 1.09 seconds
# Epoch: 103, Train loss: 0.0160, Train acc: 0.8008, Train AUC: 0.8493, Test loss: 0.5312, Test acc: 0.7640, Test auc: 0.8108
# Epoch took 1.07 seconds
# Epoch: 104, Train loss: 0.0157, Train acc: 0.8124, Train AUC: 0.8554, Test loss: 0.5151, Test acc: 0.7898, Test auc: 0.8454
# Epoch took 1.10 seconds
# Epoch: 105, Train loss: 0.0154, Train acc: 0.8231, Train AUC: 0.8640, Test loss: 0.4964, Test acc: 0.8063, Test auc: 0.8423
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.15 seconds
# Epoch: 106, Train loss: 0.0155, Train acc: 0.8198, Train AUC: 0.8634, Test loss: 0.5156, Test acc: 0.7952, Test auc: 0.8642
# Epoch took 1.13 seconds
# Epoch: 107, Train loss: 0.0155, Train acc: 0.8165, Train AUC: 0.8621, Test loss: 0.5825, Test acc: 0.7233, Test auc: 0.8501
# Epoch took 1.06 seconds
# Epoch: 108, Train loss: 0.0158, Train acc: 0.8074, Train AUC: 0.8611, Test loss: 0.5135, Test acc: 0.7890, Test auc: 0.8606
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.04 seconds
# Epoch: 109, Train loss: 0.0153, Train acc: 0.8215, Train AUC: 0.8623, Test loss: 0.5053, Test acc: 0.8023, Test auc: 0.8610
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.10 seconds
# Epoch: 110, Train loss: 0.0152, Train acc: 0.8281, Train AUC: 0.8627, Test loss: 0.5046, Test acc: 0.8050, Test auc: 0.8533
# Epoch took 1.14 seconds
# Epoch: 111, Train loss: 0.0153, Train acc: 0.8240, Train AUC: 0.8573, Test loss: 0.5157, Test acc: 0.7819, Test auc: 0.8455
# Epoch took 1.19 seconds
# Epoch: 112, Train loss: 0.0155, Train acc: 0.8132, Train AUC: 0.8664, Test loss: 0.5327, Test acc: 0.7698, Test auc: 0.8475
# Epoch took 1.08 seconds
# Epoch: 113, Train loss: 0.0154, Train acc: 0.8132, Train AUC: 0.8581, Test loss: 0.5886, Test acc: 0.7042, Test auc: 0.8363
# Epoch took 1.12 seconds
# Epoch: 114, Train loss: 0.0162, Train acc: 0.7926, Train AUC: 0.8478, Test loss: 0.5105, Test acc: 0.8015, Test auc: 0.8456
# Epoch took 1.10 seconds
# Epoch: 115, Train loss: 0.0155, Train acc: 0.8157, Train AUC: 0.8521, Test loss: 0.5133, Test acc: 0.7960, Test auc: 0.8460
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.12 seconds
# Epoch: 116, Train loss: 0.0159, Train acc: 0.8058, Train AUC: 0.8509, Test loss: 0.5213, Test acc: 0.7777, Test auc: 0.8459
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.10 seconds
# Epoch: 117, Train loss: 0.0157, Train acc: 0.8124, Train AUC: 0.8514, Test loss: 0.5110, Test acc: 0.7996, Test auc: 0.8631
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.12 seconds
# Epoch: 118, Train loss: 0.0153, Train acc: 0.8256, Train AUC: 0.8553, Test loss: 0.5111, Test acc: 0.7956, Test auc: 0.8386
# Epoch took 1.13 seconds
# Epoch: 119, Train loss: 0.0156, Train acc: 0.8066, Train AUC: 0.8652, Test loss: 0.4975, Test acc: 0.8215, Test auc: 0.8486
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.12 seconds
# Epoch: 120, Train loss: 0.0156, Train acc: 0.8058, Train AUC: 0.8610, Test loss: 0.5383, Test acc: 0.7675, Test auc: 0.8339
# Epoch took 1.10 seconds
# Epoch: 121, Train loss: 0.0161, Train acc: 0.7950, Train AUC: 0.8515, Test loss: 0.5101, Test acc: 0.7894, Test auc: 0.8369
# Epoch took 1.18 seconds
# Epoch: 122, Train loss: 0.0154, Train acc: 0.8182, Train AUC: 0.8613, Test loss: 0.5023, Test acc: 0.8152, Test auc: 0.8532
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.18 seconds
# Epoch: 123, Train loss: 0.0160, Train acc: 0.7884, Train AUC: 0.8587, Test loss: 0.4995, Test acc: 0.8148, Test auc: 0.8546
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.11 seconds
# Epoch: 124, Train loss: 0.0155, Train acc: 0.8107, Train AUC: 0.8615, Test loss: 0.5358, Test acc: 0.7640, Test auc: 0.8321
# Epoch took 1.11 seconds
# Epoch: 125, Train loss: 0.0154, Train acc: 0.8140, Train AUC: 0.8572, Test loss: 0.4981, Test acc: 0.8019, Test auc: 0.8528
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.11 seconds
# Epoch: 126, Train loss: 0.0152, Train acc: 0.8248, Train AUC: 0.8605, Test loss: 0.5133, Test acc: 0.7921, Test auc: 0.8421
# Epoch took 1.06 seconds
# Epoch: 127, Train loss: 0.0153, Train acc: 0.8165, Train AUC: 0.8678, Test loss: 0.5155, Test acc: 0.8023, Test auc: 0.8484
# Epoch took 1.09 seconds
# Epoch: 128, Train loss: 0.0151, Train acc: 0.8314, Train AUC: 0.8667, Test loss: 0.5167, Test acc: 0.7979, Test auc: 0.8480
# Epoch took 1.07 seconds
# Epoch: 129, Train loss: 0.0151, Train acc: 0.8281, Train AUC: 0.8657, Test loss: 0.5040, Test acc: 0.8113, Test auc: 0.8499
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.05 seconds
# Epoch: 130, Train loss: 0.0151, Train acc: 0.8273, Train AUC: 0.8677, Test loss: 0.5109, Test acc: 0.7948, Test auc: 0.8551
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.09 seconds
# Epoch: 131, Train loss: 0.0153, Train acc: 0.8264, Train AUC: 0.8655, Test loss: 0.5157, Test acc: 0.7952, Test auc: 0.8372
# Epoch took 1.07 seconds
# Epoch: 132, Train loss: 0.0153, Train acc: 0.8264, Train AUC: 0.8639, Test loss: 0.5255, Test acc: 0.7902, Test auc: 0.8485
# Epoch took 1.16 seconds
# Epoch: 133, Train loss: 0.0156, Train acc: 0.8091, Train AUC: 0.8645, Test loss: 0.5275, Test acc: 0.7917, Test auc: 0.8297
# Epoch took 1.18 seconds
# Epoch: 134, Train loss: 0.0153, Train acc: 0.8207, Train AUC: 0.8690, Test loss: 0.5089, Test acc: 0.8010, Test auc: 0.8537
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.11 seconds
# Epoch: 135, Train loss: 0.0154, Train acc: 0.8132, Train AUC: 0.8611, Test loss: 0.5055, Test acc: 0.8015, Test auc: 0.8450
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.13 seconds
# Epoch: 136, Train loss: 0.0153, Train acc: 0.8215, Train AUC: 0.8614, Test loss: 0.5529, Test acc: 0.7515, Test auc: 0.8569
# Epoch took 1.11 seconds
# Epoch: 137, Train loss: 0.0151, Train acc: 0.8256, Train AUC: 0.8603, Test loss: 0.5021, Test acc: 0.8077, Test auc: 0.8369
# Epoch took 1.10 seconds
# Epoch: 138, Train loss: 0.0155, Train acc: 0.8165, Train AUC: 0.8659, Test loss: 0.5250, Test acc: 0.7863, Test auc: 0.8395
# Epoch took 1.58 seconds
# Epoch: 139, Train loss: 0.0157, Train acc: 0.8058, Train AUC: 0.8654, Test loss: 0.5082, Test acc: 0.8046, Test auc: 0.8354
# Epoch took 1.57 seconds
# Epoch: 140, Train loss: 0.0155, Train acc: 0.8190, Train AUC: 0.8712, Test loss: 0.5131, Test acc: 0.7800, Test auc: 0.8535
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.63 seconds
# Epoch: 141, Train loss: 0.0153, Train acc: 0.8157, Train AUC: 0.8631, Test loss: 0.5050, Test acc: 0.7956, Test auc: 0.8386
# Epoch took 1.64 seconds
# Epoch: 142, Train loss: 0.0157, Train acc: 0.8033, Train AUC: 0.8564, Test loss: 0.5176, Test acc: 0.7890, Test auc: 0.8407
# Epoch took 1.83 seconds
# Epoch: 143, Train loss: 0.0153, Train acc: 0.8240, Train AUC: 0.8628, Test loss: 0.5074, Test acc: 0.7988, Test auc: 0.8502
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 2.59 seconds
# Epoch: 144, Train loss: 0.0152, Train acc: 0.8198, Train AUC: 0.8655, Test loss: 0.5016, Test acc: 0.8023, Test auc: 0.8441
# Epoch took 2.04 seconds
# Epoch: 145, Train loss: 0.0160, Train acc: 0.7983, Train AUC: 0.8542, Test loss: 0.5215, Test acc: 0.7890, Test auc: 0.8509
# Epoch took 1.14 seconds
# Epoch: 146, Train loss: 0.0151, Train acc: 0.8364, Train AUC: 0.8630, Test loss: 0.5114, Test acc: 0.7921, Test auc: 0.8542
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.09 seconds
# Epoch: 147, Train loss: 0.0156, Train acc: 0.8091, Train AUC: 0.8574, Test loss: 0.5210, Test acc: 0.7952, Test auc: 0.8333
# Epoch took 1.15 seconds
# Epoch: 148, Train loss: 0.0152, Train acc: 0.8289, Train AUC: 0.8658, Test loss: 0.5113, Test acc: 0.8042, Test auc: 0.8389
# Epoch took 1.09 seconds
# Epoch: 149, Train loss: 0.0151, Train acc: 0.8281, Train AUC: 0.8673, Test loss: 0.5134, Test acc: 0.8010, Test auc: 0.8538
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.15 seconds
# Epoch: 150, Train loss: 0.0153, Train acc: 0.8231, Train AUC: 0.8592, Test loss: 0.5019, Test acc: 0.8117, Test auc: 0.8584
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.19 seconds
# Epoch: 151, Train loss: 0.0151, Train acc: 0.8281, Train AUC: 0.8705, Test loss: 0.5248, Test acc: 0.7831, Test auc: 0.8444
# Epoch took 1.16 seconds
# Epoch: 152, Train loss: 0.0152, Train acc: 0.8306, Train AUC: 0.8677, Test loss: 0.4961, Test acc: 0.8117, Test auc: 0.8650
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.11 seconds
# Epoch: 153, Train loss: 0.0152, Train acc: 0.8248, Train AUC: 0.8609, Test loss: 0.5050, Test acc: 0.7988, Test auc: 0.8492
# Epoch took 1.12 seconds
# Epoch: 154, Train loss: 0.0152, Train acc: 0.8198, Train AUC: 0.8633, Test loss: 0.5085, Test acc: 0.8010, Test auc: 0.8529
# Epoch took 1.12 seconds
# Epoch: 155, Train loss: 0.0151, Train acc: 0.8347, Train AUC: 0.8663, Test loss: 0.5188, Test acc: 0.7885, Test auc: 0.8377
# Epoch took 1.12 seconds
# Epoch: 156, Train loss: 0.0151, Train acc: 0.8289, Train AUC: 0.8624, Test loss: 0.5060, Test acc: 0.8015, Test auc: 0.8403
# Epoch took 1.10 seconds
# Epoch: 157, Train loss: 0.0151, Train acc: 0.8298, Train AUC: 0.8649, Test loss: 0.5070, Test acc: 0.8042, Test auc: 0.8473
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.17 seconds
# Epoch: 158, Train loss: 0.0150, Train acc: 0.8339, Train AUC: 0.8714, Test loss: 0.4950, Test acc: 0.8085, Test auc: 0.8562
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.13 seconds
# Epoch: 159, Train loss: 0.0149, Train acc: 0.8380, Train AUC: 0.8684, Test loss: 0.4950, Test acc: 0.8094, Test auc: 0.8563
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.10 seconds
# Epoch: 160, Train loss: 0.0160, Train acc: 0.8000, Train AUC: 0.8610, Test loss: 0.4968, Test acc: 0.8148, Test auc: 0.8550
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.12 seconds
# Epoch: 161, Train loss: 0.0151, Train acc: 0.8273, Train AUC: 0.8650, Test loss: 0.4944, Test acc: 0.8179, Test auc: 0.8602
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.21 seconds
# Epoch: 162, Train loss: 0.0154, Train acc: 0.8190, Train AUC: 0.8607, Test loss: 0.5083, Test acc: 0.7881, Test auc: 0.8456
# Epoch took 1.20 seconds
# Epoch: 163, Train loss: 0.0151, Train acc: 0.8314, Train AUC: 0.8678, Test loss: 0.5064, Test acc: 0.7867, Test auc: 0.8626
# Epoch took 1.12 seconds
# Epoch: 164, Train loss: 0.0150, Train acc: 0.8289, Train AUC: 0.8657, Test loss: 0.4937, Test acc: 0.8121, Test auc: 0.8596
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.24 seconds
# Epoch: 165, Train loss: 0.0151, Train acc: 0.8256, Train AUC: 0.8702, Test loss: 0.4923, Test acc: 0.8215, Test auc: 0.8592
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.23 seconds
# Epoch: 166, Train loss: 0.0152, Train acc: 0.8223, Train AUC: 0.8612, Test loss: 0.5051, Test acc: 0.8090, Test auc: 0.8532
# Epoch took 1.16 seconds
# Epoch: 167, Train loss: 0.0152, Train acc: 0.8223, Train AUC: 0.8678, Test loss: 0.5046, Test acc: 0.8081, Test auc: 0.8527
# Epoch took 1.17 seconds
# Epoch: 168, Train loss: 0.0149, Train acc: 0.8355, Train AUC: 0.8662, Test loss: 0.4970, Test acc: 0.8077, Test auc: 0.8649
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.14 seconds
# Epoch: 169, Train loss: 0.0152, Train acc: 0.8256, Train AUC: 0.8695, Test loss: 0.4917, Test acc: 0.8027, Test auc: 0.8666
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.14 seconds
# Epoch: 170, Train loss: 0.0150, Train acc: 0.8314, Train AUC: 0.8732, Test loss: 0.4990, Test acc: 0.8085, Test auc: 0.8487
# Epoch took 1.10 seconds
# Epoch: 171, Train loss: 0.0149, Train acc: 0.8339, Train AUC: 0.8677, Test loss: 0.4948, Test acc: 0.8238, Test auc: 0.8608
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.16 seconds
# Epoch: 172, Train loss: 0.0149, Train acc: 0.8347, Train AUC: 0.8674, Test loss: 0.5240, Test acc: 0.7867, Test auc: 0.8252
# Epoch took 1.17 seconds
# Epoch: 173, Train loss: 0.0152, Train acc: 0.8264, Train AUC: 0.8618, Test loss: 0.5032, Test acc: 0.7921, Test auc: 0.8754
# Epoch took 1.21 seconds
# Epoch: 174, Train loss: 0.0149, Train acc: 0.8372, Train AUC: 0.8725, Test loss: 0.4888, Test acc: 0.8156, Test auc: 0.8664
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.11 seconds
# Epoch: 175, Train loss: 0.0149, Train acc: 0.8388, Train AUC: 0.8676, Test loss: 0.4898, Test acc: 0.8219, Test auc: 0.8549
# Epoch took 1.15 seconds
# Epoch: 176, Train loss: 0.0148, Train acc: 0.8421, Train AUC: 0.8721, Test loss: 0.4914, Test acc: 0.8183, Test auc: 0.8709
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.10 seconds
# Epoch: 177, Train loss: 0.0148, Train acc: 0.8405, Train AUC: 0.8700, Test loss: 0.5009, Test acc: 0.8019, Test auc: 0.8491
# Epoch took 1.14 seconds
# Epoch: 178, Train loss: 0.0149, Train acc: 0.8347, Train AUC: 0.8712, Test loss: 0.5155, Test acc: 0.7948, Test auc: 0.8299
# Epoch took 1.08 seconds
# Epoch: 179, Train loss: 0.0154, Train acc: 0.8198, Train AUC: 0.8633, Test loss: 0.4985, Test acc: 0.8148, Test auc: 0.8609
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.10 seconds
# Epoch: 180, Train loss: 0.0157, Train acc: 0.8074, Train AUC: 0.8613, Test loss: 0.5207, Test acc: 0.7917, Test auc: 0.8345
# Epoch took 1.11 seconds
# Epoch: 181, Train loss: 0.0151, Train acc: 0.8298, Train AUC: 0.8631, Test loss: 0.5091, Test acc: 0.7881, Test auc: 0.8449
# Epoch took 1.10 seconds
# Epoch: 182, Train loss: 0.0149, Train acc: 0.8372, Train AUC: 0.8634, Test loss: 0.5275, Test acc: 0.7796, Test auc: 0.8384
# Epoch took 1.07 seconds
# Epoch: 183, Train loss: 0.0154, Train acc: 0.8091, Train AUC: 0.8645, Test loss: 0.5071, Test acc: 0.7960, Test auc: 0.8409
# Epoch took 1.11 seconds
# Epoch: 184, Train loss: 0.0151, Train acc: 0.8281, Train AUC: 0.8696, Test loss: 0.4991, Test acc: 0.8090, Test auc: 0.8643
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.20 seconds
# Epoch: 185, Train loss: 0.0151, Train acc: 0.8298, Train AUC: 0.8693, Test loss: 0.5047, Test acc: 0.8054, Test auc: 0.8408
# Epoch took 1.11 seconds
# Epoch: 186, Train loss: 0.0149, Train acc: 0.8306, Train AUC: 0.8714, Test loss: 0.5142, Test acc: 0.7890, Test auc: 0.8446
# Epoch took 1.11 seconds
# Epoch: 187, Train loss: 0.0148, Train acc: 0.8397, Train AUC: 0.8668, Test loss: 0.5073, Test acc: 0.7917, Test auc: 0.8515
# Epoch took 1.06 seconds
# Epoch: 188, Train loss: 0.0147, Train acc: 0.8455, Train AUC: 0.8692, Test loss: 0.5142, Test acc: 0.8002, Test auc: 0.8310
# Epoch took 1.13 seconds
# Epoch: 189, Train loss: 0.0148, Train acc: 0.8388, Train AUC: 0.8713, Test loss: 0.5160, Test acc: 0.7929, Test auc: 0.8480
# Epoch took 1.12 seconds
# Epoch: 190, Train loss: 0.0151, Train acc: 0.8298, Train AUC: 0.8731, Test loss: 0.5022, Test acc: 0.7992, Test auc: 0.8557
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.11 seconds
# Epoch: 191, Train loss: 0.0150, Train acc: 0.8322, Train AUC: 0.8736, Test loss: 0.5271, Test acc: 0.7835, Test auc: 0.8219
# Epoch took 1.12 seconds
# Epoch: 192, Train loss: 0.0148, Train acc: 0.8430, Train AUC: 0.8676, Test loss: 0.5021, Test acc: 0.8023, Test auc: 0.8309
# Epoch took 1.13 seconds
# Epoch: 193, Train loss: 0.0149, Train acc: 0.8314, Train AUC: 0.8681, Test loss: 0.5052, Test acc: 0.8077, Test auc: 0.8322
# Epoch took 1.10 seconds
# Epoch: 194, Train loss: 0.0149, Train acc: 0.8380, Train AUC: 0.8682, Test loss: 0.5059, Test acc: 0.8077, Test auc: 0.8565
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.13 seconds
# Epoch: 195, Train loss: 0.0147, Train acc: 0.8446, Train AUC: 0.8719, Test loss: 0.4965, Test acc: 0.8125, Test auc: 0.8577
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.21 seconds
# Epoch: 196, Train loss: 0.0154, Train acc: 0.8157, Train AUC: 0.8627, Test loss: 0.5124, Test acc: 0.7960, Test auc: 0.8551
# Epoch took 1.12 seconds
# Epoch: 197, Train loss: 0.0149, Train acc: 0.8430, Train AUC: 0.8641, Test loss: 0.5057, Test acc: 0.8050, Test auc: 0.8471
# Epoch took 1.11 seconds
# Epoch: 198, Train loss: 0.0151, Train acc: 0.8273, Train AUC: 0.8673, Test loss: 0.4911, Test acc: 0.8152, Test auc: 0.8605
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.11 seconds
# Epoch: 199, Train loss: 0.0147, Train acc: 0.8397, Train AUC: 0.8717, Test loss: 0.5107, Test acc: 0.7948, Test auc: 0.8401
# Epoch took 1.09 seconds
# Epoch: 200, Train loss: 0.0148, Train acc: 0.8388, Train AUC: 0.8678, Test loss: 0.5225, Test acc: 0.7858, Test auc: 0.8188
# Epoch took 1.08 seconds
# Epoch: 201, Train loss: 0.0149, Train acc: 0.8413, Train AUC: 0.8751, Test loss: 0.5035, Test acc: 0.8015, Test auc: 0.8417
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.11 seconds
# Epoch: 202, Train loss: 0.0148, Train acc: 0.8397, Train AUC: 0.8776, Test loss: 0.5009, Test acc: 0.8046, Test auc: 0.8496
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.07 seconds
# Epoch: 203, Train loss: 0.0148, Train acc: 0.8388, Train AUC: 0.8681, Test loss: 0.4982, Test acc: 0.8179, Test auc: 0.8585
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.14 seconds
# Epoch: 204, Train loss: 0.0149, Train acc: 0.8388, Train AUC: 0.8691, Test loss: 0.4977, Test acc: 0.8238, Test auc: 0.8529
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.08 seconds
# Epoch: 205, Train loss: 0.0148, Train acc: 0.8405, Train AUC: 0.8683, Test loss: 0.5080, Test acc: 0.8042, Test auc: 0.8444
# Epoch took 1.16 seconds
# Epoch: 206, Train loss: 0.0150, Train acc: 0.8306, Train AUC: 0.8636, Test loss: 0.5056, Test acc: 0.7983, Test auc: 0.8454
# Epoch took 1.16 seconds
# Epoch: 207, Train loss: 0.0148, Train acc: 0.8421, Train AUC: 0.8598, Test loss: 0.5162, Test acc: 0.7933, Test auc: 0.8282
# Epoch took 1.11 seconds
# Epoch: 208, Train loss: 0.0151, Train acc: 0.8281, Train AUC: 0.8607, Test loss: 0.5084, Test acc: 0.8042, Test auc: 0.8483
# Epoch took 1.09 seconds
# Epoch: 209, Train loss: 0.0147, Train acc: 0.8479, Train AUC: 0.8669, Test loss: 0.4885, Test acc: 0.8277, Test auc: 0.8464
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.08 seconds
# Epoch: 210, Train loss: 0.0146, Train acc: 0.8438, Train AUC: 0.8719, Test loss: 0.4835, Test acc: 0.8313, Test auc: 0.8546
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.08 seconds
# Epoch: 211, Train loss: 0.0150, Train acc: 0.8322, Train AUC: 0.8639, Test loss: 0.4984, Test acc: 0.8042, Test auc: 0.8509
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.11 seconds
# Epoch: 212, Train loss: 0.0146, Train acc: 0.8479, Train AUC: 0.8729, Test loss: 0.5083, Test acc: 0.7894, Test auc: 0.8452
# Epoch took 1.10 seconds
# Epoch: 213, Train loss: 0.0149, Train acc: 0.8339, Train AUC: 0.8698, Test loss: 0.5056, Test acc: 0.7952, Test auc: 0.8424
# Epoch took 1.12 seconds
# Epoch: 214, Train loss: 0.0146, Train acc: 0.8430, Train AUC: 0.8701, Test loss: 0.4904, Test acc: 0.8246, Test auc: 0.8595
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.12 seconds
# Epoch: 215, Train loss: 0.0148, Train acc: 0.8347, Train AUC: 0.8726, Test loss: 0.5049, Test acc: 0.8050, Test auc: 0.8437
# Epoch took 1.05 seconds
# Epoch: 216, Train loss: 0.0148, Train acc: 0.8421, Train AUC: 0.8631, Test loss: 0.5168, Test acc: 0.7988, Test auc: 0.8287
# Epoch took 1.16 seconds
# Epoch: 217, Train loss: 0.0150, Train acc: 0.8322, Train AUC: 0.8668, Test loss: 0.5036, Test acc: 0.8073, Test auc: 0.8376
# Epoch took 1.17 seconds
# Epoch: 218, Train loss: 0.0148, Train acc: 0.8421, Train AUC: 0.8708, Test loss: 0.5042, Test acc: 0.8023, Test auc: 0.8670
# Epoch took 1.08 seconds
# Epoch: 219, Train loss: 0.0146, Train acc: 0.8430, Train AUC: 0.8725, Test loss: 0.4935, Test acc: 0.8152, Test auc: 0.8525
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.11 seconds
# Epoch: 220, Train loss: 0.0145, Train acc: 0.8504, Train AUC: 0.8717, Test loss: 0.4909, Test acc: 0.8117, Test auc: 0.8520
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.12 seconds
# Epoch: 221, Train loss: 0.0149, Train acc: 0.8347, Train AUC: 0.8715, Test loss: 0.4997, Test acc: 0.8019, Test auc: 0.8568
# Epoch took 1.10 seconds
# Epoch: 222, Train loss: 0.0148, Train acc: 0.8364, Train AUC: 0.8710, Test loss: 0.5014, Test acc: 0.8050, Test auc: 0.8592
# Epoch took 1.13 seconds
# Epoch: 223, Train loss: 0.0153, Train acc: 0.8240, Train AUC: 0.8676, Test loss: 0.5044, Test acc: 0.8046, Test auc: 0.8316
# Epoch took 1.12 seconds
# Epoch: 224, Train loss: 0.0147, Train acc: 0.8455, Train AUC: 0.8677, Test loss: 0.4990, Test acc: 0.8015, Test auc: 0.8519
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.10 seconds
# Epoch: 225, Train loss: 0.0146, Train acc: 0.8463, Train AUC: 0.8767, Test loss: 0.4955, Test acc: 0.8179, Test auc: 0.8569
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.15 seconds
# Epoch: 226, Train loss: 0.0145, Train acc: 0.8479, Train AUC: 0.8695, Test loss: 0.5127, Test acc: 0.7917, Test auc: 0.8414
# Epoch took 1.10 seconds
# Epoch: 227, Train loss: 0.0146, Train acc: 0.8421, Train AUC: 0.8756, Test loss: 0.4983, Test acc: 0.8042, Test auc: 0.8591
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.21 seconds
# Epoch: 228, Train loss: 0.0148, Train acc: 0.8372, Train AUC: 0.8729, Test loss: 0.5291, Test acc: 0.7742, Test auc: 0.8153
# Epoch took 1.18 seconds
# Epoch: 229, Train loss: 0.0152, Train acc: 0.8231, Train AUC: 0.8607, Test loss: 0.5204, Test acc: 0.7788, Test auc: 0.8444
# Epoch took 1.14 seconds
# Epoch: 230, Train loss: 0.0151, Train acc: 0.8314, Train AUC: 0.8573, Test loss: 0.5051, Test acc: 0.8046, Test auc: 0.8517
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.24 seconds
# Epoch: 231, Train loss: 0.0147, Train acc: 0.8430, Train AUC: 0.8721, Test loss: 0.4857, Test acc: 0.8152, Test auc: 0.8704
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.52 seconds
# Epoch: 232, Train loss: 0.0146, Train acc: 0.8446, Train AUC: 0.8716, Test loss: 0.5114, Test acc: 0.7863, Test auc: 0.8477
# Epoch took 1.29 seconds
# Epoch: 233, Train loss: 0.0152, Train acc: 0.8240, Train AUC: 0.8709, Test loss: 0.4937, Test acc: 0.8152, Test auc: 0.8573
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.33 seconds
# Epoch: 234, Train loss: 0.0150, Train acc: 0.8322, Train AUC: 0.8664, Test loss: 0.4949, Test acc: 0.8183, Test auc: 0.8629
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.17 seconds
# Epoch: 235, Train loss: 0.0148, Train acc: 0.8388, Train AUC: 0.8692, Test loss: 0.5223, Test acc: 0.7804, Test auc: 0.8215
# Epoch took 1.14 seconds
# Epoch: 236, Train loss: 0.0151, Train acc: 0.8256, Train AUC: 0.8640, Test loss: 0.4888, Test acc: 0.8085, Test auc: 0.8596
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.13 seconds
# Epoch: 237, Train loss: 0.0148, Train acc: 0.8364, Train AUC: 0.8707, Test loss: 0.5296, Test acc: 0.7706, Test auc: 0.8346
# Epoch took 1.37 seconds
# Epoch: 238, Train loss: 0.0150, Train acc: 0.8339, Train AUC: 0.8601, Test loss: 0.5086, Test acc: 0.7992, Test auc: 0.8420
# Epoch took 1.27 seconds
# Epoch: 239, Train loss: 0.0146, Train acc: 0.8455, Train AUC: 0.8714, Test loss: 0.4984, Test acc: 0.8113, Test auc: 0.8497
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.13 seconds
# Epoch: 240, Train loss: 0.0148, Train acc: 0.8388, Train AUC: 0.8782, Test loss: 0.5006, Test acc: 0.8081, Test auc: 0.8433
# Epoch took 1.09 seconds
# Epoch: 241, Train loss: 0.0147, Train acc: 0.8413, Train AUC: 0.8727, Test loss: 0.5208, Test acc: 0.7956, Test auc: 0.8315
# Epoch took 1.10 seconds
# Epoch: 242, Train loss: 0.0146, Train acc: 0.8471, Train AUC: 0.8772, Test loss: 0.4956, Test acc: 0.8050, Test auc: 0.8527
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.08 seconds
# Epoch: 243, Train loss: 0.0145, Train acc: 0.8529, Train AUC: 0.8771, Test loss: 0.5098, Test acc: 0.8077, Test auc: 0.8261
# Epoch took 1.23 seconds
# Epoch: 244, Train loss: 0.0148, Train acc: 0.8372, Train AUC: 0.8698, Test loss: 0.5038, Test acc: 0.8113, Test auc: 0.8400
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.10 seconds
# Epoch: 245, Train loss: 0.0144, Train acc: 0.8479, Train AUC: 0.8752, Test loss: 0.4949, Test acc: 0.8117, Test auc: 0.8478
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.12 seconds
# Epoch: 246, Train loss: 0.0143, Train acc: 0.8570, Train AUC: 0.8754, Test loss: 0.5039, Test acc: 0.7996, Test auc: 0.8479
# Epoch took 1.10 seconds
# Epoch: 247, Train loss: 0.0146, Train acc: 0.8479, Train AUC: 0.8752, Test loss: 0.5076, Test acc: 0.7979, Test auc: 0.8380
# Epoch took 1.09 seconds
# Epoch: 248, Train loss: 0.0146, Train acc: 0.8521, Train AUC: 0.8616, Test loss: 0.4911, Test acc: 0.8183, Test auc: 0.8490
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.20 seconds
# Epoch: 249, Train loss: 0.0150, Train acc: 0.8306, Train AUC: 0.8627, Test loss: 0.4944, Test acc: 0.8050, Test auc: 0.8568
# Saving model to: drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool.pth
# Epoch took 1.20 seconds
# Saved model epoch is 249
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-43-d64a54fb59b2> in <cell line: 35>()
#      43       epochs = nb_epochs,
#      44       model_save_path = model_save_path)
# ---> 45   with open(f"bace_gcn_models_path/{i}_{num_hidden_channels}_{nb_epochs}_{pool_method.__name__}_results.pkl", 'wb') as f:
#      46     print("entered with open pickle")
#      47     pickle.dump(results, f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'bace_gcn_models_path/0_128_250_global_mean_pool_results.pkl'

# %%
loaded_model = GCNClassifier(num_features, num_hidden_channels, num_out_channels, pool_method)

# Load a random model
model_save_path = bace_gcn_models_path/"0_128_150_global_mean_pool.pth"

print(model_save_path)
loaded_model.load_state_dict(torch.load(f=model_save_path))

loaded_model.eval()

with torch.inference_mode():
    loaded_model_preds = loaded_model(next(iter(test_dataloader)))
# loaded_model_preds
# Out:
# drive/MyDrive/bace_graph_project/models/gcn_models/0_128_150_global_mean_pool.pth

# %%
auroc_metric = BinaryAUROC(thresholds=100)

# Function which gives the AUC of a model and its metrics, as given by Scikit-Learn's classification report

def new_metric_func(model, train_dataloader, test_dataloader):
  with torch.inference_mode():
    model.eval()

    # Create empty tensors to fill with probabilities, predictions and labels
    total_train_probs = torch.empty(len(train_dataset))
    total_train_preds = torch.empty(len(train_dataset))
    total_train_labels = torch.empty(len(train_dataset))

    total_test_probs = torch.empty(len(test_dataset))
    total_test_preds = torch.empty(len(test_dataset))
    total_test_labels = torch.empty(len(test_dataset))

    # Loop over batches and add to the total tensors
    for idx, batch in enumerate(train_dataloader):
      batch = batch.to(device)
      batch_size = 32
      current_batch_size = len(batch)
      # print(f"{idx*batch_size}:{idx*batch_size+current_batch_size}")
      out = model.forward(batch)
      train_probs = out[:,1]
      train_preds = torch.argmax(out, dim=1)

      total_train_probs[idx*batch_size:idx*batch_size+current_batch_size] = train_probs
      total_train_preds[idx*batch_size:idx*batch_size+current_batch_size] = train_preds
      total_train_labels[idx*batch_size:idx*batch_size+current_batch_size] = batch.Class

    for idx, batch in enumerate(test_dataloader):
      batch = batch.to(device)
      batch_size = 32
      current_batch_size = len(batch)
      # print(f"{idx*batch_size}:{idx*batch_size+current_batch_size}")
      out = model.forward(batch)
      test_probs = out[:,1]
      test_preds = torch.argmax(out, dim=1)

      total_test_probs[idx*batch_size:idx*batch_size+current_batch_size] = test_probs
      total_test_preds[idx*batch_size:idx*batch_size+current_batch_size] = test_preds
      total_test_labels[idx*batch_size:idx*batch_size+current_batch_size] = batch.Class

    # Calculate AUC and dataframes of metrics (using Scikit-Learn's metrics)
    train_auroc = auroc_metric(total_train_probs, total_train_labels).item()
    train_classification_report = classification_report(total_train_labels, total_train_preds, output_dict=True)
    train_report_df = pd.DataFrame(data=train_classification_report).transpose()

    test_auroc = auroc_metric(total_test_probs, total_test_labels).item()
    test_classification_report = classification_report(total_test_labels, total_test_preds, output_dict=True)
    test_report_df = pd.DataFrame(data=test_classification_report).transpose()


  return train_auroc, test_auroc, train_report_df, test_report_df

# %%
torch.manual_seed(42)
loaded_model = loaded_model.to(device)
train_auroc, test_auroc, train_classification_report, test_classification_report = new_metric_func(loaded_model, train_dataloader, test_dataloader)
print(train_auroc, test_auroc)
display(train_classification_report, test_classification_report)
# Out:
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# 0.6799682974815369 0.6704137921333313
#               precision    recall  f1-score      support
# 0.0            0.606371  0.806354  0.692208   661.000000
# 1.0            0.613293  0.369763  0.461364   549.000000
# accuracy       0.608264  0.608264  0.608264     0.608264
# macro avg      0.609832  0.588059  0.576786  1210.000000
# weighted avg   0.609512  0.608264  0.587469  1210.000000
#               precision    recall  f1-score     support
# 0.0            0.596330  0.807453  0.686016  161.000000
# 1.0            0.635294  0.380282  0.475771  142.000000
# accuracy       0.607261  0.607261  0.607261    0.607261
# macro avg      0.615812  0.593868  0.580893  303.000000
# weighted avg   0.614591  0.607261  0.587485  303.000000

# %%
print(train_auroc)

# %%
start_time = timer()
train_auroc, test_auroc, train_report_df, test_report_df = new_metric_func(model, train_dataloader, test_dataloader)
end_time = timer()
print(round(end_time-start_time, 4))
# Out:
# 5.5292

# %%
def loss_acc_auc_plots(results):

  fig, ax = plt.subplots(ncols=3, nrows=1, figsize = (14,6))

  ax[0].plot(results["epoch"], results["train_loss"], label="Train");
  ax[0].plot(results["epoch"], results["test_loss"],  label="Test");

  ax[1].plot(results["epoch"], results["train_acc"], label="Train");
  ax[1].plot(results["epoch"], results["test_acc"],  label="Test");

  ax[2].plot(results["epoch"], results["train_auc"], label="Train");
  ax[2].plot(results["epoch"], results["test_auc"],  label="Test");

  ax[0].set_xlabel("Epochs", size=14)
  ax[0].set_ylabel("Loss", size=14)

  ax[1].set_xlabel("Epochs", size=14)
  ax[1].set_ylabel("Accuracy", size=14)

  ax[2].set_xlabel("Epochs", size=14)
  ax[2].set_ylabel("AUC", size=14)

  ax[0].legend();
  ax[1].legend();
  ax[2].legend();

# %%
loss_acc_auc_plots(results)

# %%
with open('/content/drive/MyDrive/bace_graph_project/models/gcn_models/0_128_250_global_mean_pool_results.pkl', 'rb') as f:
    loaded_dict = pickle.load(f)


def moving_average(data, window_size):
    return np.convolve(data, np.ones(window_size)/window_size, mode='valid')
mov_avg_vals = moving_average(loaded_dict["test_loss"], 20)

plt.plot(loaded_dict["test_loss"])
plt.plot(mov_avg_vals)

# %%
# GAT Classifier Training Run

display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 300})'''))

torch.manual_seed(42)

train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=True)

# Number of features of the graphs
num_features = next(iter(train_dataloader)).x.shape[1]
num_hidden_channels = 64
num_out_channels = 2
heads=4
# with no edge attributes, global mean pooling best is 70 epochs
nb_epochs = 70
use_edge_attr = True
pool_method = global_mean_pool

# Instantiating GAT Classifier
gat_model = GATClassifier(num_features, num_hidden_channels, num_out_channels, heads, pool_method, use_edge_attr)

# Instantiate optimizer and loss function
adam_optimizer = torch.optim.Adam(gat_model.parameters(), lr=0.001, weight_decay=1e-4)
sgd_optimizer = torch.optim.SGD(gat_model.parameters())
criterion = torch.nn.CrossEntropyLoss()


gat_results = train(gat_model,
      train_dataloader,
      test_dataloader,
      adam_optimizer,
      loss_fn = criterion,
      epochs = nb_epochs)

# %%
print(type(adam_optimizer))

# %%
loss_and_acc_plots(gat_results)

# %%
# GraphConv Classifier Training Run

display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 300})'''))

torch.manual_seed(42)

train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=True)

# Number of features of the graphs
num_features = next(iter(train_dataloader)).x.shape[1]
num_hidden_channels = 64
num_out_channels = 2
# global mean pooling, best is 50 epochs
nb_epochs = 50
pool_method = global_mean_pool

# Instantiating GAT Classifier
graphconv_model = GraphConvClassifier(num_features, num_hidden_channels, num_out_channels, pool_method)

# Instantiate optimizer and loss function
adam_optimizer = torch.optim.Adam(graphconv_model.parameters(), lr=0.001, weight_decay=1e-4)
sgd_optimizer = torch.optim.SGD(graphconv_model.parameters())
criterion = torch.nn.CrossEntropyLoss()

"""
graphconv_results = train(graphconv_model,
      train_dataloader,
      test_dataloader,
      adam_optimizer,
      loss_fn = criterion,
      epochs = nb_epochs)
"""

# %%
# loss_and_acc_plots(graphconv_results)

# %%
# GINConv Classifier Training Run

display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 300})'''))

torch.manual_seed(42)

train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=True)

# Number of features of the graphs
num_features = next(iter(train_dataloader)).x.shape[1]
num_hidden_channels = 64
num_out_channels = 2
num_layers = 3
nb_epochs = 50
pool_method = global_mean_pool

# Instantiating GINConv Classifier
ginconv_model = GINConvClassifier(num_features, num_hidden_channels, num_out_channels, num_layers, pool_method)

# Instantiate optimizer and loss function
adam_optimizer = torch.optim.Adam(ginconv_model.parameters(), lr=0.001, weight_decay=1e-4)
sgd_optimizer = torch.optim.SGD(ginconv_model.parameters())
criterion = torch.nn.CrossEntropyLoss()


ginconv_results = train(ginconv_model,
      train_dataloader,
      test_dataloader,
      adam_optimizer,
      loss_fn = criterion,
      epochs = nb_epochs)

# %%
# loss_and_acc_plots(ginconv_results)

# %%
# GINEConv Classifier Training Run

display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 300})'''))

torch.manual_seed(42)

train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=True)

# Number of features of the graphs
num_features = next(iter(train_dataloader)).x.shape[1]
num_hidden_channels = 64
num_out_channels = 2
num_layers = 3
# best number of epochs with edge attributes is about 15
nb_epochs = 15
pool_method = global_mean_pool
use_edge_attr = True
edge_dim = dataset[0].edge_attr.shape[1]

# Instantiating GINEConv Classifier
gineconv_model = GINEConvClassifier(num_features, num_hidden_channels, num_out_channels, num_layers, pool_method, use_edge_attr, edge_dim)

# Instantiate optimizer and loss function
adam_optimizer = torch.optim.Adam(gineconv_model.parameters(), lr=0.001, weight_decay=1e-4)
sgd_optimizer = torch.optim.SGD(gineconv_model.parameters())
criterion = torch.nn.CrossEntropyLoss()


gineconv_results = train(gineconv_model,
      train_dataloader,
      test_dataloader,
      adam_optimizer,
      loss_fn = criterion,
      epochs = nb_epochs)

# %%
loss_and_acc_plots(gineconv_results)

# %%
gat_train_auroc, gat_test_auroc, gat_train_report_df, gat_test_report_df = metric_func(gat_model, train_dataset, test_dataset)
"""
graphconv_train_auroc, graphconv_test_auroc, graphconv_train_report_df, graphconv_test_report_df = metric_func(graphconv_model, train_dataset, test_dataset)

ginconv_train_auroc, ginconv_test_auroc, ginconv_train_report_df, ginconv_test_report_df = metric_func(ginconv_model, train_dataset, test_dataset)
"""
gineconv_train_auroc, gineconv_test_auroc, gineconv_train_report_df, gineconv_test_report_df = metric_func(gineconv_model, train_dataset, test_dataset)

# %%
"""
print("GCN results:")
display("train AUC:", train_auroc, "test AUC:", test_auroc, train_report_df, test_report_df)
"""
print("GAT results:")
display("train AUC:", gat_train_auroc, "test AUC:", gat_test_auroc, gat_train_report_df, gat_test_report_df)
"""
print("GraphConv results:")
display("train AUC:", graphconv_train_auroc, "test AUC:", graphconv_test_auroc, graphconv_train_report_df, graphconv_test_report_df)

print("GinConv results:")
display("train AUC:", ginconv_train_auroc, "test AUC:", ginconv_test_auroc, ginconv_train_report_df, ginconv_test_report_df)
"""
print("GineConv results:")
display("train AUC:", gineconv_train_auroc, "test AUC:", gineconv_test_auroc, gineconv_train_report_df, gineconv_test_report_df)
